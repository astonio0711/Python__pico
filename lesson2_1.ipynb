# %%
5
type(5)
# Out:
# int

# %%
5.0
type(5.0)
# Out:
# float

# %%
'5.0'
type('5.0')
# Out:
# str

# %%
True
type(True)
# Out:
# bool

# %%
5 + 5
# Out:
# 10

# %%
5.0 + 5.0
# Out:
# 10.0

# %%
'5.0' + '5.0'
# Out:
# '5.05.0'

# %%
5 + 5.0
# Out:
# 10.0

# %%
'5.0' + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /workspaces/Python__pico/lesson2_1.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Breimagined-chainsaw-g4qw7469vp9qhw55r/workspaces/Python__pico/lesson2_1.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> '5.0' + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
int ('5') + 5
# Out:
# 10

# %%
float ('5.5') + 5
# Out:
# 10.5

# %%
5 + 8
# Out:
# 13

# %%
90 - 10
# Out:
# 80

# %%
4 * 7
# Out:
# 28

# %%
#浮點數除法
7 / 2
# Out:
# 3.5

# %%
#整數除法
7 // 2
# Out:
# 3

# %%
#餘數
7 % 3
# Out:
# 1

# %%
#次方
3 ** 4
# Out:
# 81

# %%
99 ** 99
# Out:
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %%
n = 5 + 5
n
# Out:
# 10

# %%
n = 2 + 3 * 4
n
# Out:
# 14

# %%
z = 2 * (1 + 2) ** 2 - 2 ** 2 * 2
z
# Out:
# 10

# %%
import math

side = int(input("請輸入對邊(整數)"))
another_Side = int(input("請輸入斜邊(整數)"))

radians = math.asin(side/another_Side)
degrees = math.degrees(radians)

print(f"斜邊：{another_Side}，對邊：{side}")
print(f"弳度：{radians:.2f}，角度：{degrees:.2f}")
# Out:
# 斜邊：50，對邊：25
# 弳度：0.52，角度：30.00
