# %%
#學生總分為300
#有些學生可以加分5%
#如果加分超過300以300
#輸入超過300分, 出現警告

scores = int(input("請輸入學生分數"))
if scores <= 300:
    is_add = input("學生是否符合加分條件?(y,n)")

    if is_add == 'y':
        scores *=1.05
        if scores > 300: scores = 300
    print(f"輸入學生分數為:{scores}")

else: print("輸入錯誤")
# Out:
# 輸入錯誤

# %%
try:
    money = int(input("請輸入金額:"))
    print(money)
except ValueError:
    print("輸入數值格式錯誤")
# Out:
# 輸入數值錯誤

# %%
#學生總分為300
#有些學生可以加分5%
#如果加分超過300以300
#輸入超過300分, 出現警告

try:
    scores = int(input("請輸入學生分數"))
    if scores <= 300:
        is_add = input("學生是否符合加分條件?(y,n)")

        if is_add == 'y':
            scores *=1.05
            if scores > 300: scores = 300
        print(f"輸入學生分數為:{scores}")

    else: print("輸入錯誤")
except ValueError as err:
    print(f"輸入錯誤{err}")
except TypeError as err:
    print(f"類型錯誤{err}")
except:
    print("不知名的錯誤")
# Out:
# 輸入錯誤invalid literal for int() with base 10: '100a'
